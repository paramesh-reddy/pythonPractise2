# %% [markdown]
# <a href="https://colab.research.google.com/github/paramesh-reddy/pythonPractise2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
data =[1,2,3,4,5,]
index = ['a','b','c','d','e']
series = pd.Series(data, index = index)
print (series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame([[1,2,3],[4,5,6,],[7,8,9,]],columns=['c1','c2','c3'],index=['r1','r2','r3'])
print(df  )
# Out:
#     c1  c2  c3
# r1   1   2   3
# r2   4   5   6
# r3   7   8   9

# %%
df.columns
# Out:
# Index(['c1', 'c2', 'c3'], dtype='object')

# %%
df.index
# Out:
# Index(['r1', 'r2', 'r3'], dtype='object')

# %%
# customer_data = pd.read_csv('customer.csv')
customer_data = pd.read_csv('/customer.csv')

# %%
customer_data.head(1)
# Out:
#    Index      Customer Id First Name Last Name        Company         City  \
# 0      1  dE014d010c7ab0c     Andrew   Goodman  Stewart-Flynn  Rowlandberg
#
#   Country            Phone 1              Phone 2  \
# 0   Macao  846-790-4623x4715  (422)787-2331x71127
#
#                            Email Subscription Date               Website
# 0  marieyates@gomez-spencer.info        2021-07-26  http://www.shea.biz/

# %%
customer_data.size
# Out:
# 12000

# %%
customer_data.tail(1)
# Out:
#      Index      Customer Id First Name Last Name     Company        City  \
# 999   1000  51732B5b2328015    Dominic     Duran  Durham LLC  East Wendy
#
#                                                Country          Phone 1  \
# 999  British Indian Ocean Territory (Chagos Archipe...  +1-278-758-4331
#
#               Phone 2                   Email Subscription Date  \
# 999  814-860-0941x057  owarner@velasquez.info        2021-12-09
#
#                  Website
# 999  http://www.cox.com/

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              1000 non-null   int64
#  1   Customer Id        1000 non-null   object
#  2   First Name         1000 non-null   object
#  3   Last Name          1000 non-null   object
#  4   Company            1000 non-null   object
#  5   City               1000 non-null   object
#  6   Country            1000 non-null   object
#  7   Phone 1            1000 non-null   object
#  8   Phone 2            1000 non-null   object
#  9   Email              1000 non-null   object
#  10  Subscription Date  1000 non-null   object
#  11  Website            1000 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 93.9+ KB

# %%
customer_data.loc[0:10 , 'Last Name']
# Out:
# 0     Goodman
# 1        Lane
# 2     Harding
# 3        Ford
# 4       Woods
# 5      Gamble
# 6      Cooley
# 7       Villa
# 8      Bryant
# 9     Estrada
# 10     Cannon
# Name: Last Name, dtype: object

# %%
customer_data.loc[0:5, "Index":"City"]
# Out:
#    Index      Customer Id First Name Last Name                      Company  \
# 0      1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1      2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2      3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3      4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4      5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
# 5      6  8aaa5d0CE9ee311    Marissa    Gamble              Cherry and Sons
#
#                City
# 0       Rowlandberg
# 1          Bethside
# 2      Moniquemouth
# 3        Leeborough
# 4  Port Jacksonland
# 5         Webertown

# %%
customer_data.iloc[0:5,0:5]
# Out:
#    Index      Customer Id First Name Last Name                      Company
# 0      1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1      2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2      3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3      4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4      5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley

# %%
customer_data.at[0,"Company"]
# Out:
# 'Stewart-Flynn'

# %%
customer_data.iat[0,1]
# Out:
# 'dE014d010c7ab0c'

# %%
customer_data.loc[(customer_data['City'] == "First Name")]
# Out:
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website]
# Index: []

# %%
 customer_data.head(1)
# Out:
#    Index      Customer Id First Name Last Name        Company         City  \
# 0      1  dE014d010c7ab0c     Andrew   Goodman  Stewart-Flynn  Rowlandberg
#
#   Country            Phone 1              Phone 2  \
# 0   Macao  846-790-4623x4715  (422)787-2331x71127
#
#                            Email Subscription Date               Website
# 0  marieyates@gomez-spencer.info        2021-07-26  http://www.shea.biz/

# %%
customer_data.loc[1,"City"]="newww"

# %%
customer_data.loc[0:5, "Id"] =5

# %%
customer_data.head()
# Out:
#    Index      Customer Id First Name Last Name                      Company  \
# 0      1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1      2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2      3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3      4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4      5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
#
#                City           Country                Phone 1  \
# 0       Rowlandberg             Macao      846-790-4623x4715
# 1             newww  Papua New Guinea     124-597-8652x05682
# 2      Moniquemouth             China     (335)987-3085x3780
# 3        Leeborough             Macao          (047)752-3122
# 4  Port Jacksonland             Nepal  +1-360-693-4419x19272
#
#                Phone 2                          Email Subscription Date  \
# ...

# %%
customer_data.loc[0:3,"Last Name"]="olddd"

# %%
customer_data.head(5)
# Out:
#    Index      Customer Id First Name Last Name                      Company  \
# 0      1  dE014d010c7ab0c     Andrew     olddd                Stewart-Flynn
# 1      2  2B54172c8b65eC3      Alvin     olddd  Terry, Proctor and Lawrence
# 2      3  d794Dd48988d2ac      Jenna     olddd                 Bailey Group
# 3      4  3b3Aa4aCc68f3Be   Fernando     olddd                 Moss-Maxwell
# 4      5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
#
#                City           Country                Phone 1  \
# 0       Rowlandberg             Macao      846-790-4623x4715
# 1             newww  Papua New Guinea     124-597-8652x05682
# 2      Moniquemouth             China     (335)987-3085x3780
# 3        Leeborough             Macao          (047)752-3122
# 4  Port Jacksonland             Nepal  +1-360-693-4419x19272
#
#                Phone 2                          Email Subscription Date  \
# ...

# %%
customer_data.iloc[0:2,3]='whooooo'

# %%
customer_data.head(5)
# Out:
#    Index      Customer Id First Name Last Name                      Company  \
# 0      1  dE014d010c7ab0c     Andrew   whooooo                Stewart-Flynn
# 1      2  2B54172c8b65eC3      Alvin   whooooo  Terry, Proctor and Lawrence
# 2      3  d794Dd48988d2ac      Jenna     olddd                 Bailey Group
# 3      4  3b3Aa4aCc68f3Be   Fernando     olddd                 Moss-Maxwell
# 4      5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
#
#                City           Country                Phone 1  \
# 0       Rowlandberg             Macao      846-790-4623x4715
# 1             newww  Papua New Guinea     124-597-8652x05682
# 2      Moniquemouth             China     (335)987-3085x3780
# 3        Leeborough             Macao          (047)752-3122
# 4  Port Jacksonland             Nepal  +1-360-693-4419x19272
#
#                Phone 2                          Email Subscription Date  \
# ...

# %%
customer_data.at[2,"Customer Id"]="Whyyyy"

# %%
customer_data.head(3)
# Out:
#    Index      Customer Id First Name Last Name                      Company  \
# 0      1  dE014d010c7ab0c     Andrew   whooooo                Stewart-Flynn
# 1      2  2B54172c8b65eC3      Alvin   whooooo  Terry, Proctor and Lawrence
# 2      3           Whyyyy      Jenna     olddd                 Bailey Group
#
#            City           Country             Phone 1              Phone 2  \
# 0   Rowlandberg             Macao   846-790-4623x4715  (422)787-2331x71127
# 1         newww  Papua New Guinea  124-597-8652x05682    321.441.0588x6218
# 2  Moniquemouth             China  (335)987-3085x3780     001-680-204-8312
#
#                            Email Subscription Date  \
# 0  marieyates@gomez-spencer.info        2021-07-26
# 1          alexandra86@mccoy.com        2021-06-24
# 2        justincurtis@pierce.org        2020-04-05
#
#                        Website   Id
# 0         http://www.shea.biz/  5.0
# 1    http://www.pena-cole.com/  5.0
# 2  http://www.booth-reese.biz/  5.0

# %%
def City (x):
  return x+'whooo'
customer_data["City"]=customer_data["City"].apply(City)
customer_data['City']
# Out:
# 0               Rowlandbergwhooo
# 1                     newwwwhooo
# 2              Moniquemouthwhooo
# 3                Leeboroughwhooo
# 4          Port Jacksonlandwhooo
#                  ...
# 995       Lake Jacksonmouthwhooo
# 996    South Dominiquemouthwhooo
# 997         East Chloeshirewhooo
# 998             South Shanewhooo
# 999              East Wendywhooo
# Name: City, Length: 1000, dtype: object

# %%
customer_data.insert(2,"Bmi", 20)

# %%
customer_data.head(4)
# Out:
#    Index      Customer Id  Bmi First Name Last Name  \
# 0      1  dE014d010c7ab0c   20     Andrew   whooooo
# 1      2  2B54172c8b65eC3   20      Alvin   whooooo
# 2      3           Whyyyy   20      Jenna     olddd
# 3      4  3b3Aa4aCc68f3Be   20   Fernando     olddd
#
#                        Company               City           Country  \
# 0                Stewart-Flynn   Rowlandbergwhooo             Macao
# 1  Terry, Proctor and Lawrence         newwwwhooo  Papua New Guinea
# 2                 Bailey Group  Moniquemouthwhooo             China
# 3                 Moss-Maxwell    Leeboroughwhooo             Macao
#
#               Phone 1              Phone 2                          Email  \
# 0   846-790-4623x4715  (422)787-2331x71127  marieyates@gomez-spencer.info
# 1  124-597-8652x05682    321.441.0588x6218          alexandra86@mccoy.com
# 2  (335)987-3085x3780     001-680-204-8312        justincurtis@pierce.org
# ...

# %%
customer_data.drop(columns="Bmi")
# Out:
#      Index      Customer Id First Name Last Name                      Company  \
# 0        1  dE014d010c7ab0c     Andrew   whooooo                Stewart-Flynn
# 1        2  2B54172c8b65eC3      Alvin   whooooo  Terry, Proctor and Lawrence
# 2        3           Whyyyy      Jenna     olddd                 Bailey Group
# 3        4  3b3Aa4aCc68f3Be   Fernando     olddd                 Moss-Maxwell
# 4        5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
# ..     ...              ...        ...       ...                          ...
# 995    996  FbcCaF483aFaFAE      Diana    Monroe                  Bass-Wilson
# 996    997  979c4D58Ae9a9cc      Jerry   Morales                   Pratt-King
# 997    998  D0DcF6a4BcefCc8     Tracie     Floyd     Holt, Wilson and Shields
# 998    999  90EE9CbbDa374E9       Paul    Barnes     Brown, Oliver and Haynes
# 999   1000  51732B5b2328015    Dominic     Duran                   Durham LLC
#
# ...

# %%
customer_data.drop(columns="Bmi" ,inplace=True)

# %%
customer_data.head(5)
# Out:
#    Index      Customer Id First Name Last Name                      Company  \
# 0      1  dE014d010c7ab0c     Andrew   whooooo                Stewart-Flynn
# 1      2  2B54172c8b65eC3      Alvin   whooooo  Terry, Proctor and Lawrence
# 2      3           Whyyyy      Jenna     olddd                 Bailey Group
# 3      4  3b3Aa4aCc68f3Be   Fernando     olddd                 Moss-Maxwell
# 4      5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
#
#                     City           Country                Phone 1  \
# 0       Rowlandbergwhooo             Macao      846-790-4623x4715
# 1             newwwwhooo  Papua New Guinea     124-597-8652x05682
# 2      Moniquemouthwhooo             China     (335)987-3085x3780
# 3        Leeboroughwhooo             Macao          (047)752-3122
# 4  Port Jacksonlandwhooo             Nepal  +1-360-693-4419x19272
#
#                Phone 2                          Email Subscription Date  \
# ...

# %%
customer_data.insert(2, "hello", 50)

# %%
customer_data.head(5)
# Out:
#    Index      Customer Id  hello First Name Last Name  \
# 0      1  dE014d010c7ab0c     50     Andrew   whooooo
# 1      2  2B54172c8b65eC3     50      Alvin   whooooo
# 2      3           Whyyyy     50      Jenna     olddd
# 3      4  3b3Aa4aCc68f3Be     50   Fernando     olddd
# 4      5  D60df62ad2ae41E     50       Kara     Woods
#
#                        Company                   City           Country  \
# 0                Stewart-Flynn       Rowlandbergwhooo             Macao
# 1  Terry, Proctor and Lawrence             newwwwhooo  Papua New Guinea
# 2                 Bailey Group      Moniquemouthwhooo             China
# 3                 Moss-Maxwell        Leeboroughwhooo             Macao
# 4              Mccarthy-Kelley  Port Jacksonlandwhooo             Nepal
#
#                  Phone 1              Phone 2                          Email  \
# 0      846-790-4623x4715  (422)787-2331x71127  marieyates@gomez-spencer.info
# ...

# %%
 customer_data= customer_data.drop(columns=['New bmi','hello'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3343161185.py in <cell line: 0>()
# ----> 1 customer_data= customer_data.drop(columns=['New bmi','hello'],inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
# del  customer_data [ "First Name"]

# %%
customer_data.head(5)

# %%
customer_data.rename(columns={"Bmi":'Category'},inplace=True)

# %%
customer_data.head(5)

# %%
df1= pd.DataFrame({
    'id':[1,2,3],
    'name':['ravi','amit','youtube']

})
df2 = pd.DataFrame({
    "id":[3,4,5,],
    "course":['java','python','c',]
})
inner_result= pd.merge(df1,df2, how='inner', on='id')
inner_result

# %%
df1= pd.DataFrame({
    'id':[1,2,3],
    'name':['ravi','amit','youtube']

})
df2 = pd.DataFrame({
    "id":[3,4,5,],
    "course":['java','python','c',]
})
outer_result= pd.merge(df1,df2, how='outer', on='id')
outer_result

# %%
df1= pd.DataFrame({
    'id':[1,2,3],
    'name':['ravi','amit','youtube']

})
df2 = pd.DataFrame({
    "id":[3,4,5,],
    "course":['java','python','c',]
})
outer_result= pd.merge(df1,df2, how='outer', on='id')
outer_result

# %%
df1= pd.DataFrame({
    'id':[1,2,3],
    'name':['ravi','amit','youtube']

})
df2 = pd.DataFrame({
    "id":[3,4,5,],
    "course":['java','python','c',]
})
right_result= pd.merge(df1,df2, how='right', on='id')
right_result

# %%
df1= pd.DataFrame({
    'id':[1,2,3],
    'name':['ravi','amit','youtube']

})
df2 = pd.DataFrame({
    "id":[3,4,5,],
    "course":['java','python','c',]
})
left_result= pd.merge(df1,df2, how='left', on='id')
left_result

# %%
df3= pd.DataFrame({
    'id2':[1,2,3],
    'name':['ravi','amit','youtube']

})
df4 = pd.DataFrame({
    "id3":[3,4,5,],
    "course":['java','python','c',]
})
inner_result= pd.merge (df3,df4, how='inner', left_on='id2',right_on='id3')
inner_result

# %%
df1= pd.DataFrame({
    'id':[1,2,3],
    'name':['ravi','amit','youtube']

})
df2 = pd.DataFrame({
    "id":[3,4,5,],
    "course":['java','python','c',]
})
result= pd.concat([df1,df2], axis=0 ,ignore_index=True)
result

# %%
df1= pd.DataFrame({
    'id':[1,2,3],
    'name':['ravi','amit','youtube']

})
df2 = pd.DataFrame({
    "id":[3,4,5,],
    "course":['java','python','c',]
})
result2= pd.concat([df1,df2], axis=1 ,)
result2

# %%
result.isna()

# %%
result.notna()

# %%
result.isna().sum()

# %%
result.notna().sum()

# %%
# result.fillna(20 , inplace=True)

# %%
result.dropna(inplace=True)

# %%
customer_data.groupby("Last Name").count()

# %%
customer_data.describe()

# %%
customer_data.sample(2,random_state=1)

# %%
customer_data.columns.tolist()

# %%
customer_data.index
